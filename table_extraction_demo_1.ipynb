# %% [markdown]
# # Table Detection Demo
# The purpose of this demo is to propose different table extraction formats to the client:
# 1. Table as a 2D json array with texts represented as a string
# 2. Table as a 1D json array with texts represented as a string and cell bounding box coordinates

# %% [markdown]
# # Install Requirements

# %%
# !sudo yum install ghostscript -y
# !sudo yum update -y
# !sudo yum install ImageMagick-devel -y
# !pip install pdfplumber

# %% [markdown]
# # Imports

# %%
import pandas as pd
import pdfplumber
import json
import layoutparser as lp
import os
pdfplumber.__version__
# Out:
# '0.6.0'

# %% [markdown]
# # Extract Tables from Sample SOPs
# Here we try to extract tables from sample documents suggested by the client.
# 1. LAB-2352 (Andover) - suggested by the client
# 2. MCD-088122 (Kalamazoo) - suggested by us to show complex table examples

# %%
def cell_to_textblock(cell, text):
    return lp.TextBlock(
        block=lp.Rectangle(
            x_1=cell[0],
            y_1=cell[1],
            
            x_2=cell[2],
            y_2=cell[3],
        ),
        text=text,
        id=None,
        type='CELL',
        parent=None,
        next=None,
        score=None,
    )

# %%
def table_to_layout(table, table_texts):
    textblocks = []
    for row, row_texts in zip(table.rows, table_texts):
        for cell, cell_text in zip(row.cells, row_texts):
            if cell:
                textblocks.append(cell_to_textblock(cell,  cell_text))
    
    layout = lp.Layout(textblocks)
    
    return layout

# %%
def images_to_pdf(images, filename):
    all_images = []
    for images_per_page in images:
        all_images.extend(images_per_page)
        
    if all_images:
        all_images[0].save(filename, "PDF" ,resolution=100.0, save_all=True, append_images=all_images[1:])

# %%
def tables_to_csv(tables, dir):
    if not os.path.exists(dir):
        os.mkdir(dir)
        
    for page_idx, page_tables in enumerate(tables, start=1):
        for table_idx, table in enumerate(page_tables, start=1):
            table.to_csv(f"{dir}/table_{page_idx}_{table_idx}.csv")

# %%
def tables_to_json(tables, dir):
    if not os.path.exists(dir):
        os.mkdir(dir)
        
    for page_idx, page_tables in enumerate(tables, start=1):
        for table_idx, table in enumerate(page_tables, start=1):
            with open(f"{dir}/table_{page_idx}_{table_idx}.json", 'w') as file:
                json.dump(table, file)

# %%
TABLE_EXTRACTION_SETTINGS = {'snap_tolerance':4, 'edge_min_length':30}

# %%
def detect_tables(filename):
    pdf_layout, pdf_images = lp.load_pdf(filename, load_images=True)
    pdf = pdfplumber.open(filename)
    
    pdf_images_with_table_boxes = []
    table_dfs_per_page = []
    table_texts_per_page = []
    table_jsons_bbox_per_page = []
    for page, page_img in zip(pdf.pages, pdf_images):
        page_table_finder = page.debug_tablefinder(table_settings=TABLE_EXTRACTION_SETTINGS)
        page_tables = page_table_finder.tables
        page_tables_texts = page.extract_tables(table_settings=TABLE_EXTRACTION_SETTINGS)
        
        _images_with_table_boxes = []
        _dfs_per_page = []
        _texts_per_page = []
        _jsons_bbox_per_page = []
        for table, table_texts in zip(page_tables, page_tables_texts):
            # create layout from table to draw bounding boxes
            table_layout = table_to_layout(table, table_texts)
            table_layout.page_data.update({"width":page_img.size[0], "height":page_img.size[1]})
            page_img_with_table_boxes = lp.draw_box(page_img, table_layout, box_width=2)
            _images_with_table_boxes.append(page_img_with_table_boxes)
            
            # convert to dataframe
            table_df = pd.DataFrame(table_texts)
            _dfs_per_page.append(table_df)
            
            # convert to json texts
            _texts_per_page.append(table_texts)
            
            # convert to json texts and bounding boxes
            _jsons_bbox_per_page.append(table_layout.to_dict())
        
        pdf_images_with_table_boxes.append(_images_with_table_boxes)
        table_dfs_per_page.append(_dfs_per_page)
        table_texts_per_page.append(_texts_per_page)
        table_jsons_bbox_per_page.append(_jsons_bbox_per_page)
        
    return pdf_images_with_table_boxes, table_dfs_per_page, table_texts_per_page, table_jsons_bbox_per_page

# %%
SOP_DIR = "data/sop"
RESULTS_DIR = "Table Extraction Demo 1"

SOPS_INFO = [
    {"type": "Andover", "id":"LAB-2352"},
    {"type": "Kalamazoo", "id":"MCD-088122"},
    {"type": "UNK", "id":"19897"},

]

# %%
for sop in SOPS_INFO:
    _subdir =   os.path.join(RESULTS_DIR, f"{sop['type']}_{sop['id']}")
    _sop_file_path = os.path.join(SOP_DIR, sop['type'], f"{sop['id']}.pdf")
    _sop_pdf_tables_file = os.path.join(_subdir, f"{sop['id']}.pdf")
    _sop_csv_tables_dir = os.path.join(_subdir, "csv")
    _sop_json_table_texts_dir = os.path.join(_subdir, "text")
    _sop_json_table_bbox_dir = os.path.join(_subdir, "bbox")
    if not os.path.exists(_subdir):
        os.makedirs(_subdir)
    
    images_with_table_boxes, table_dfs, table_texts, table_bboxes = detect_tables(filename=_sop_file_path)
    
    images_to_pdf(images=images_with_table_boxes, filename=_sop_pdf_tables_file)
    tables_to_csv(tables=table_dfs, dir=_sop_csv_tables_dir)
    tables_to_json(tables=table_texts, dir=_sop_json_table_texts_dir)
    tables_to_json(tables=table_bboxes, dir=_sop_json_table_bbox_dir)

# %%
# !zip -r demo.zip Table\ Extraction\ Demo\ 1
# Out:
#   adding: Table Extraction Demo 1/ (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/ (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/ (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_5_2.csv (deflated 58%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_5_3.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_3_2.csv (deflated 53%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_14_2.csv (deflated 63%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_21_5.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_5_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_16_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_17_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_10_2.csv (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_20_2.csv (deflated 47%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_5_5.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_9_3.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_21_4.csv (deflated 34%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_18_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_15_2.csv (deflated 66%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_18_3.csv (deflated 24%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_21_3.csv (deflated 19%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_9_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_10_3.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_19_2.csv (deflated 55%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_1_3.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_12_2.csv (deflated 48%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_13_2.csv (deflated 63%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_16_2.csv (deflated 66%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_22_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_1_1.csv (deflated 29%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_18_4.csv (deflated 49%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_9_2.csv (deflated 41%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_10_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_2_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_6_2.csv (deflated 39%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/.ipynb_checkpoints/ (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/.ipynb_checkpoints/table_1_2-checkpoint.csv (deflated 24%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/.ipynb_checkpoints/table_3_2-checkpoint.csv (deflated 53%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/.ipynb_checkpoints/table_10_1-checkpoint.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/.ipynb_checkpoints/table_1_1-checkpoint.csv (deflated 29%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/.ipynb_checkpoints/table_1_3-checkpoint.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/.ipynb_checkpoints/table_1_4-checkpoint.csv (deflated 14%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_1_4.csv (deflated 14%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_5_6.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_11_2.csv (deflated 47%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_7_2.csv (deflated 43%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_3_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_19_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_11_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_2_3.csv (deflated 43%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_21_2.csv (deflated 53%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_7_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_12_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_4_2.csv (deflated 48%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_14_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_24_1.csv (deflated 29%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_20_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_6_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_11_3.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_8_1.csv (deflated 63%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_22_2.csv (deflated 20%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_5_4.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_4_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_2_2.csv (deflated 33%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_12_3.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_8_2.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_15_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_17_2.csv (deflated 47%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_13_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_21_6.csv (deflated 19%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_21_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_17_3.csv (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_1_2.csv (deflated 24%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_23_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/csv/table_18_2.csv (deflated 11%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/ (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_11_1.json (deflated 63%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_19_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_18_3.json (deflated 74%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_5_3.json (deflated 70%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_20_2.json (deflated 79%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_10_1.json (deflated 63%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_9_3.json (deflated 67%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_14_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_3_2.json (deflated 91%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_16_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_5_4.json (deflated 66%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_6_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_2_3.json (deflated 89%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_8_1.json (deflated 88%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_21_3.json (deflated 90%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_10_2.json (deflated 88%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_20_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_12_3.json (deflated 52%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_21_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_9_1.json (deflated 52%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_18_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_10_3.json (deflated 50%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_4_2.json (deflated 86%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_11_3.json (deflated 62%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_21_5.json (deflated 50%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_13_2.json (deflated 92%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/.ipynb_checkpoints/ (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/.ipynb_checkpoints/table_3_2-checkpoint.json (deflated 91%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_17_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_3_1.json (deflated 63%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_4_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_5_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_12_1.json (deflated 63%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_24_1.json (deflated 60%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_12_2.json (deflated 84%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_11_2.json (deflated 82%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_23_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_14_2.json (deflated 92%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_18_2.json (deflated 85%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_2_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_19_2.json (deflated 82%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_7_2.json (deflated 86%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_1_3.json (deflated 69%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_2_2.json (deflated 71%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_21_6.json (deflated 52%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_15_2.json (deflated 92%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_13_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_1_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_17_2.json (deflated 62%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_15_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_18_4.json (deflated 81%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_9_2.json (deflated 85%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_22_2.json (deflated 71%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_6_2.json (deflated 85%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_5_5.json (deflated 65%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_17_3.json (deflated 51%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_21_2.json (deflated 74%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_1_4.json (deflated 81%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_5_2.json (deflated 88%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_5_6.json (deflated 51%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_21_4.json (deflated 72%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_7_1.json (deflated 63%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_1_2.json (deflated 79%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_22_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_8_2.json (deflated 72%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/bbox/table_16_2.json (deflated 92%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/.ipynb_checkpoints/ (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/.ipynb_checkpoints/MCD-088122-checkpoint.pdf (deflated 25%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/MCD-088122.pdf (deflated 25%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/ (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_11_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_19_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_18_3.json (deflated 41%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_5_3.json (deflated 2%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_20_2.json (deflated 61%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_10_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_9_3.json (deflated 10%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_14_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_3_2.json (deflated 81%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_16_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_5_4.json (deflated 9%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_6_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_2_3.json (deflated 65%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_8_1.json (deflated 83%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_21_3.json (deflated 58%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_10_2.json (deflated 80%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_20_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_12_3.json (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_21_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_9_1.json (deflated 28%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_18_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_10_3.json (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_4_2.json (deflated 56%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_11_3.json (deflated 10%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_21_5.json (deflated 24%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_13_2.json (deflated 89%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/.ipynb_checkpoints/ (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/.ipynb_checkpoints/table_1_1-checkpoint.json (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/.ipynb_checkpoints/table_1_4-checkpoint.json (deflated 33%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/.ipynb_checkpoints/table_1_2-checkpoint.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_17_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_3_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_4_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_5_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_12_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_24_1.json (deflated 29%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_12_2.json (deflated 74%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_11_2.json (deflated 71%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_23_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_14_2.json (deflated 89%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_18_2.json (deflated 41%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_2_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_19_2.json (deflated 63%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_7_2.json (deflated 68%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_1_3.json (deflated 5%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_2_2.json (deflated 38%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_21_6.json (deflated 19%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_15_2.json (deflated 90%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_13_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_1_1.json (deflated 30%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_17_2.json (deflated 48%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_15_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_18_4.json (deflated 57%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_9_2.json (deflated 65%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_22_2.json (deflated 36%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_6_2.json (deflated 64%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_5_5.json (deflated 14%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_17_3.json (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_21_2.json (deflated 57%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_1_4.json (deflated 33%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_5_2.json (deflated 78%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_5_6.json (stored 0%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_21_4.json (deflated 40%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_7_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_1_2.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_22_1.json (deflated 32%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_8_2.json (deflated 14%)
#   adding: Table Extraction Demo 1/Kalamazoo_MCD-088122/text/table_16_2.json (deflated 90%)
#   adding: Table Extraction Demo 1/UNK_19897/ (stored 0%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/ (stored 0%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_5_1.csv (deflated 5%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_16_1.csv (deflated 64%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_17_1.csv (deflated 84%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_20_2.csv (deflated 4%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_18_1.csv (deflated 84%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_1_1.csv (deflated 30%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/.ipynb_checkpoints/ (stored 0%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/.ipynb_checkpoints/table_1_1-checkpoint.csv (deflated 30%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_11_2.csv (deflated 46%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_19_1.csv (deflated 84%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_11_1.csv (deflated 44%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_21_2.csv (deflated 30%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_12_1.csv (deflated 49%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_20_4.csv (deflated 30%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_20_1.csv (deflated 38%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_6_1.csv (stored 0%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_20_3.csv (deflated 43%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_15_1.csv (deflated 25%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_13_1.csv (deflated 45%)
#   adding: Table Extraction Demo 1/UNK_19897/csv/table_21_1.csv (deflated 41%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/ (stored 0%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_11_1.json (deflated 71%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_19_1.json (deflated 94%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_20_2.json (deflated 75%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_16_1.json (deflated 92%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_6_1.json (deflated 72%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_20_1.json (deflated 47%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_21_1.json (deflated 48%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_18_1.json (deflated 95%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_20_4.json (deflated 46%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/.ipynb_checkpoints/ (stored 0%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/.ipynb_checkpoints/table_1_1-checkpoint.json (deflated 81%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_17_1.json (deflated 94%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_5_1.json (deflated 80%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_12_1.json (deflated 65%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_11_2.json (deflated 76%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_13_1.json (deflated 68%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_1_1.json (deflated 81%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_15_1.json (deflated 74%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_21_2.json (deflated 46%)
#   adding: Table Extraction Demo 1/UNK_19897/bbox/table_20_3.json (deflated 49%)
#   adding: Table Extraction Demo 1/UNK_19897/19897.pdf (deflated 14%)
#   adding: Table Extraction Demo 1/UNK_19897/.ipynb_checkpoints/ (stored 0%)
#   adding: Table Extraction Demo 1/UNK_19897/.ipynb_checkpoints/19897-checkpoint.pdf (deflated 14%)
#   adding: Table Extraction Demo 1/UNK_19897/text/ (stored 0%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_11_1.json (deflated 46%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_19_1.json (deflated 91%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_20_2.json (deflated 22%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_16_1.json (deflated 82%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_6_1.json (deflated 10%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_20_1.json (deflated 39%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_21_1.json (deflated 41%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_18_1.json (deflated 90%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_20_4.json (deflated 31%)
#   adding: Table Extraction Demo 1/UNK_19897/text/.ipynb_checkpoints/ (stored 0%)
#   adding: Table Extraction Demo 1/UNK_19897/text/.ipynb_checkpoints/table_1_1-checkpoint.json (deflated 37%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_17_1.json (deflated 90%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_5_1.json (deflated 16%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_12_1.json (deflated 50%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_11_2.json (deflated 48%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_13_1.json (deflated 46%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_1_1.json (deflated 37%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_15_1.json (deflated 27%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_21_2.json (deflated 30%)
#   adding: Table Extraction Demo 1/UNK_19897/text/table_20_3.json (deflated 45%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/ (stored 0%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/ (stored 0%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_5_2.csv (deflated 30%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_14_2.csv (deflated 52%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_6_3.csv (deflated 24%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_5_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_16_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_15_2.csv (deflated 55%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_9_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_16_2.csv (deflated 43%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_1_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_10_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_2_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_6_2.csv (deflated 32%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_7_2.csv (deflated 51%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_3_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_6_4.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_11_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_7_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_12_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_14_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_6_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_8_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_4_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_8_2.csv (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_15_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_13_1.csv (deflated 23%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/csv/table_1_2.csv (deflated 34%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/LAB-2352.pdf (deflated 15%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/ (stored 0%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_11_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_10_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_14_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_16_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_6_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_8_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_9_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/.ipynb_checkpoints/ (stored 0%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/.ipynb_checkpoints/table_1_1-checkpoint.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/.ipynb_checkpoints/table_1_2-checkpoint.json (deflated 83%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_3_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_4_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_5_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_12_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_14_2.json (deflated 74%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_2_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_7_2.json (deflated 71%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_15_2.json (deflated 78%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_6_4.json (deflated 74%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_13_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_1_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_15_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_6_2.json (deflated 70%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_5_2.json (deflated 76%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_6_3.json (deflated 87%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_7_1.json (deflated 64%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_1_2.json (deflated 83%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_8_2.json (deflated 86%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/bbox/table_16_2.json (deflated 82%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/.ipynb_checkpoints/ (stored 0%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/.ipynb_checkpoints/LAB-2352-checkpoint.pdf (deflated 15%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/ (stored 0%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_11_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_10_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_14_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_16_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_6_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_8_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_9_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/.ipynb_checkpoints/ (stored 0%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/.ipynb_checkpoints/table_6_1-checkpoint.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/.ipynb_checkpoints/table_1_1-checkpoint.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/.ipynb_checkpoints/table_11_1-checkpoint.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/.ipynb_checkpoints/table_5_1-checkpoint.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/.ipynb_checkpoints/table_4_1-checkpoint.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/.ipynb_checkpoints/table_1_2-checkpoint.json (deflated 38%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_3_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_4_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_5_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_12_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_14_2.json (deflated 55%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_2_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_7_2.json (deflated 53%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_15_2.json (deflated 58%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_6_4.json (deflated 29%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_13_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_1_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_15_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_6_2.json (deflated 36%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_5_2.json (deflated 36%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_6_3.json (deflated 51%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_7_1.json (deflated 25%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_1_2.json (deflated 38%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_8_2.json (deflated 43%)
#   adding: Table Extraction Demo 1/Andover_LAB-2352/text/table_16_2.json (deflated 51%)
